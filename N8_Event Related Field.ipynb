# %% [markdown]
# # Event-related Fields

# %% [markdown]
# Event-related fields (ERFs) and event-related potentials (ERPs) are neural responses that are time-locked to specific sensory, cognitive, or motor events. These responses reflect phase-locked neuronal activity elicited by discrete stimuli and are typically measured using magnetoencephalography (MEG) and electroencephalography (EEG), respectively. Both ERFs and ERPs are widely utilized in cognitive and clinical neuroscience to investigate the temporal dynamics of brain processing, enabling researchers to assess how the brain responds to particular tasks or sensory inputs [1,2].
#
# The objective of this section is to compute ERFs in response to visual stimuli and to perform basic visualizations of their temporal evolution and spatial distribution. Specifically, we will analyze the time course of the ERFs and generate topographical maps to illustrate the distribution of activity across the scalp. These analyses provide valuable insights into the timing and localization of brain processes associated with the perception of visual input.

# %% [markdown]
# ## Preparation
# Import the relevant modules

# %%
import os.path as op
import os
import mne
from mne_bids import BIDSPath, read_raw_bids 
from mne.viz import plot_evoked_topo
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# File overview
#
# The chapter relies on the input file (embedded in the BIDS structure):
#
# < BIDS_ROOT >/derivatives/Analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_epo.fif
#
# #### Set the local paths of the data:

# %%
subject = '01'
session = '01'
task = 'SpAtt'  
run = '01'  
meg_suffix = 'meg'
epo_suffix = 'epo'
data_path='C:/Users/rakshita/Documents/Sub_OJ_new'

bids_root = op.join(data_path, "Fieldline_Spatt_BIDS")
deriv_root = op.join(bids_root, "derivatives/analysis")
bids_path = BIDSPath(subject=subject, session=session,
            task=task, run=run, suffix=epo_suffix, datatype='meg',
            root=deriv_root, extension='.fif', check=False)
print(bids_path.basename,bids_path.fpath)
# Out:
# sub-01_ses-01_task-SpAtt_run-01_epo.fif C:\Users\rakshita\Documents\Sub_OJ_new\Fieldline_Spatt_BIDS\derivatives\analysis\sub-01\ses-01\meg\sub-01_ses-01_task-SpAtt_run-01_epo.fif

# %% [markdown]
# ## Read the epochs
#
# To read in the epochs identified in the previous chapter write

# %%
epochs = mne.read_epochs(bids_path.fpath,
                         proj = False,
                         preload=True,
                         verbose=False)

# %%
epochs
# Out:
# <EpochsFIF | 349 events (all good), -0.75 – 2 s (baseline off), ~483.5 MiB, data loaded,
#  'cueLeft': 176
#  'cueRight': 173>

# %% [markdown]
# ## Averaging the trial data
#
# Identify the epochs for the condition with respect to the onset of the left and right cue onset, and then average over trials. Subsequently, apply a bandpass filter at 0.1-30 Hz and crop the data to the time interval from -0.1 to 0.4 s from stimulus onset.

# %%
evoked_left= epochs['cueLeft'].average(method='mean').filter(0.0, 30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0))
evoked_right= epochs['cueRight'].average(method='mean').filter(0.0, 30).crop(-0.1,0.4).apply_baseline(baseline=(-0.1, 0))
# Out:
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 441 samples (0.441 s)
#
# Applying baseline correction (mode: mean)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 441 samples (0.441 s)
#
# Applying baseline correction (mode: mean)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %% [markdown]
# A butterfly-plot allows for visualising the event-related fields across sensors:

# %%
evoked_left.plot(gfp=True);

# %% [markdown]
# ## To plot a topographic map of the response at any specific instant of time write:

# %%
evoked_left.plot_topomap(times=[0.160],
    contours = 0,
    ch_type='mag',
    size=3,
    show_names=False,
    extrapolate = 'local',
    outlines = 'head'
);
# Out:
# <MNEFigure size 450x490 with 2 Axes>

# %% [markdown]
# **Question 1**: Explain how an equivalent current dipole (ECD) can account for the posterior event-related field by drawing the ECD on top of the topographic plot (hint: consider the 'right-hand rule')

# %% [markdown]
# Now plot the topographic maps across multiple time points

# %%
time_ins1 = np.linspace(0.01, 0.1, num=10) #define time points
time_ins2 = np.linspace(0.11, 0.2, num=10) #define time points
time_ins3 = np.linspace(0.21, 0.3, num=10) #define time points
time_ins4 = np.linspace(0.31, 0.4, num=10) #define time points
evoked_left.plot_topomap(times=time_ins1, ch_type='mag', extrapolate = 'local', contours = 0, outlines = None,vlim = (-300,300));
evoked_left.plot_topomap(times=time_ins2, ch_type='mag', extrapolate = 'local', contours = 0, outlines = None,vlim = (-300,300));
evoked_left.plot_topomap(times=time_ins3, ch_type='mag', extrapolate = 'local', contours = 0, outlines = None,vlim = (-300,300));
evoked_left.plot_topomap(times=time_ins4, ch_type='mag', extrapolate = 'local', contours = 0, outlines = None,vlim = (-300,300));
# Out:
# <MNEFigure size 1500x220 with 11 Axes>
# <MNEFigure size 1500x220 with 11 Axes>
# <MNEFigure size 1500x220 with 11 Axes>
# <MNEFigure size 1500x220 with 11 Axes>

# %% [markdown]
# **Question 2**: Generate the ERFs with respect to the onset of the gratings.

# %% [markdown]
# ## Preregistration and publications
#
# Publication, example:
#
# "Prior to the computation of event-related fields (ERFs), the MEG data were band-pass filtered between 0.1 and 30 Hz to attenuate slow drifts and high-frequency noise. This filtering was performed using a non-causal finite impulse response (FIR) filter, designed with a Hamming window and a filter length of 331 samples. Following filtering, epochs were averaged across trials and baseline correction was then applied by subtracting the mean signal within a 100 ms pre-stimulus interval."

# %% [markdown]
# ## References
# 1. Woodman, G. F. (2010). A brief introduction to the use of event-related potentials in studies of perception and attention. *Attention, Perception, & Psychophysics*, *72*(8), 2031–2046. https://doi.org/10.3758/APP.72.8.2031
#
# 2. Luck, S. J. (2014). *An Introduction to the Event-Related Potential Technique* (2nd ed.). Bradford Books.

# %%
evoked_left.info['chs']
# Out:
# [{'scanno': 1,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01135715,  0.10639368,  0.02660782,  0.98924732,  0.13921902,
#           0.03565365, -0.01929711,  0.37444776, -0.92671102, -0.142     ,
#           0.91680002,  0.3734    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L102_bz-s73',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 2,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01141437,  0.08433936,  0.07054138,  0.98358798,  0.12846632,
#           0.12676853, -0.00661664,  0.72753686, -0.68594259, -0.1806    ,
#           0.67379999,  0.71640003]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L104_bz-s80',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 3,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01162352,  0.04166291,  0.09666285,  0.98415393,  0.05036785,
#           0.16751556,  0.00119344,  0.95517373, -0.29420894, -0.17479999,
#           0.28999999,  0.94080001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L106_bz-s84',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 4,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01326612, -0.00788883,  0.1039995 ,  0.99151105, -0.02150538,
#           0.12507074,  0.01113379,  0.99624008,  0.08303498, -0.1266    ,
#          -0.081     ,  0.98879999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L108_bz-s77',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 5,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01390601, -0.05814681,  0.09479471,  0.99320883, -0.03169213,
#           0.10696095, -0.02750402,  0.85919899,  0.50997192, -0.1084    ,
#          -0.50999999,  0.85339999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L110_bz-s76',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 6,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01406098, -0.09231495,  0.0533032 ,  0.9960385 , -0.07243916,
#           0.04584041, -0.00706282,  0.46348694,  0.8858875 , -0.0854    ,
#          -0.88319999,  0.4614    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L112_bz-s44',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 7,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.01156522, -0.08904078, -0.055001  ,  0.98924732, -0.14487833,
#           0.        ,  0.        ,  0.        ,  0.99962872, -0.1454    ,
#          -0.9892    ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L116_bz-s37',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 8,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.03264092,  0.1049074 ,  0.0035119 , -0.89813244, -0.43067345,
#          -0.08885116, -0.01067029, -0.18062241,  0.98335928, -0.43979999,
#           0.884     ,  0.1576    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L201_bz-s86',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 9,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.03688994,  0.05126734,  0.08088462, -0.84550083, -0.21222411,
#          -0.48953027, -0.02347821, -0.90166688,  0.43144685, -0.5334    ,
#           0.37639999,  0.75760001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L205_bz-s87',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 10,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-3.96267399e-02,  4.30480490e-04,  9.18196812e-02, -8.65308404e-01,
#          -5.09337848e-03, -5.00848889e-01, -1.31249577e-02, -9.99043703e-01,
#           3.28355394e-02, -5.00599980e-01,  3.50000001e-02,  8.64799976e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L207_bz-s75',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 11,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.04310481, -0.05540222,  0.0827347 , -0.86417657,  0.24221845,
#          -0.4402943 ,  0.00289847, -0.87349087, -0.48622116, -0.50319999,
#          -0.42160001,  0.75440001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L209_bz-s52',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 12,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.04653349, -0.07779107,  0.0665469 , -0.03621958, -0.63101304,
#          -0.77475947,  0.83189827, -0.44851613,  0.32640904, -0.55360001,
#          -0.63279998,  0.54140002]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L210_bz-s65',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 13,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.04335866, -0.08846987,  0.03833961, -0.84776455,  0.51952463,
#          -0.10186757, -0.03798845, -0.25152552, -0.96663183, -0.5284    ,
#          -0.81639999,  0.2332    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L211_bz-s46',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 14,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.04426129, -0.09126364, -0.02226959, -0.86417657,  0.50198078,
#           0.        ,  0.00110436,  0.00190119, -0.9994626 , -0.50260001,
#          -0.8646    , -0.0022    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L213_bz-s48',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 15,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.03483651, -0.07502668, -0.08622859, -0.86417657,  0.50254667,
#           0.        ,  0.0011056 ,  0.00190119, -0.99974704, -0.50260001,
#          -0.8646    , -0.0022    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L215_bz-s47',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 16,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.0525783 ,  0.08520912,  0.02708546,  0.70345217,  0.63554049,
#           0.31805319, -0.04412733,  0.48569995, -0.87293732, -0.70920002,
#           0.6002    ,  0.3698    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L302_bz-s83',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 17,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.05640348,  0.05040149,  0.06320893,  0.71646857,  0.36785513,
#           0.59252971, -0.00296129,  0.85096776, -0.52471828, -0.69760001,
#           0.37419999,  0.61080003]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L304_bz-s71',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 18,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.05857127,  0.00168486,  0.07702421,  0.73853987,  0.03904923,
#           0.67289191, -0.01431511,  0.99902785, -0.04226384, -0.67379999,
#           0.0216    ,  0.73879999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L306_bz-s67',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 19,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.05922366, -0.02112503,  0.07606741, -0.03169213,  0.95812112,
#           0.2835314 , -0.6973629 ,  0.18194623, -0.69278902, -0.71579999,
#          -0.2198    ,  0.66280001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L307_bz-s42',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 20,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.06244974, -0.06528548,  0.04856427, -0.00396152,  0.56989247,
#           0.82173175, -0.69538993,  0.58877122, -0.4116807 , -0.7184    ,
#          -0.57300001,  0.39399999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L309_bz-s68',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 21,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.06303937, -0.07493576,  0.01876934,  0.7317487 , -0.66610074,
#           0.14487833, -0.01155054,  0.20043316,  0.97986203, -0.6814    ,
#          -0.71880001,  0.139     ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L310_bz-s45',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 22,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.05541101, -0.06608129, -0.05374287,  0.73457837, -0.6785512 ,
#           0.00339559, -0.01280905, -0.00886203,  1.00009739, -0.67839998,
#          -0.73479998, -0.0152    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L312_bz-s49',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 23,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.06593953,  0.07346218, -0.00313289, -0.44934916, -0.84380305,
#          -0.29145443, -0.07626124, -0.28884017,  0.95380998, -0.89020002,
#           0.45100001,  0.0654    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L401_bz-s85',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 24,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.07216588,  0.04652318,  0.03775177, -0.41482738, -0.54216188,
#          -0.73005092, -0.02339219, -0.79582345,  0.60429871, -0.90939999,
#           0.26820001,  0.31799999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L403_bz-s81',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 25,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-7.47153834e-02,  3.84073413e-04,  5.47418557e-02, -4.23316360e-01,
#           2.49009617e-02, -9.05489504e-01, -1.97890215e-02, -9.99412775e-01,
#          -1.82324853e-02, -9.05600011e-01,  1.02000004e-02,  4.23799992e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L405_bz-s82',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 26,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.0770233 , -0.04842418, -0.024257  , -0.40294284,  0.91511035,
#           0.        ,  0.        ,  0.        , -1.00007796, -0.91540003,
#          -0.403     ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L409_bz-s43',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 27,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.0787875 ,  0.03689311,  0.01238994, -0.12846632, -0.69949067,
#           0.70288622,  0.26394498,  0.65908694,  0.70414406, -0.95599997,
#           0.27579999,  0.1002    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L503_bz-s79',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 28,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.08242738, -0.01134866,  0.0226152 , -0.05546124, -0.77872097,
#          -0.62478775,  0.26268253, -0.6151647 ,  0.74340916, -0.96340001,
#          -0.1228    ,  0.2388    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L505_bz-s74',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 29,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.08752548, -0.02696323, -0.03      ,  0.        ,  0.        ,
#           1.        , -0.1908    ,  0.98159999,  0.        , -0.98159999,
#          -0.1908    ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L507_bz-s70',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 30,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.08130674,  0.02497151, -0.027001  ,  0.        ,  0.        ,
#           1.        ,  0.15000001,  0.98860002,  0.        , -0.98860002,
#           0.15000001,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L603_bz-s78',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 31,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.08405276,  0.00121397, -0.0296    ,  0.01697793,  0.99943405,
#           0.        ,  0.        ,  0.        , -0.99952281, -0.99980003,
#           0.017     ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L605_bz-s72',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 32,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([-0.08542075,  0.00123723, -0.088     ,  0.01697793,  0.99943405,
#           0.        ,  0.        ,  0.        , -0.99952281, -0.99980003,
#           0.017     ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'L607_bz-s9',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 33,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01086149,  0.10658155,  0.0261342 , -0.01929711, -0.37444776,
#           0.92671102,  0.98924732, -0.13921902, -0.03565365,  0.142     ,
#           0.91680002,  0.3734    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R102_bz-s4',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 34,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01143408,  0.08666337,  0.07227769, -0.00661664, -0.72753686,
#           0.68594259,  0.98358798, -0.12846632, -0.12676853,  0.1806    ,
#           0.67379999,  0.71640003]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R104_bz-s11',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 35,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01287893, -0.00747448,  0.10499493,  0.01113379, -0.99624008,
#          -0.08303498,  0.99151105,  0.02150538, -0.12507074,  0.1266    ,
#          -0.081     ,  0.98879999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R108_bz-s12',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 36,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01311637, -0.05628972,  0.09268799, -0.02750402, -0.85919899,
#          -0.50997192,  0.99320883,  0.03169213, -0.10696095,  0.1084    ,
#          -0.50999999,  0.85339999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R110_bz-s1',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 37,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01370269, -0.0935279 ,  0.05450488, -0.00706282, -0.46348694,
#          -0.8858875 ,  0.9960385 ,  0.07243916, -0.04584041,  0.0854    ,
#          -0.88319999,  0.4614    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R112_bz-s39',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 38,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 1.33279571e-02, -1.04289897e-01,  3.47714894e-03, -7.07413710e-04,
#           4.94906632e-03, -9.99920785e-01,  9.89813268e-01,  1.41482741e-01,
#           0.00000000e+00,  1.41399994e-01, -9.90000010e-01, -4.99999989e-03]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R114_bz-s35',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 39,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.01062777, -0.08610059, -0.05450119,  0.        ,  0.        ,
#          -0.99962872,  0.98924732,  0.14487833,  0.        ,  0.1454    ,
#          -0.9892    ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R116_bz-s36',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 40,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.0332712 ,  0.10495528,  0.00402218, -0.01067029,  0.18062241,
#          -0.98335928, -0.89813244,  0.43067345,  0.08885116,  0.43979999,
#           0.884     ,  0.1576    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R201_bz-s6',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 41,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.03731174,  0.0890405 ,  0.04990773,  0.00692326,  0.61430877,
#          -0.78857046, -0.85342389,  0.41426146,  0.31522354,  0.52039999,
#           0.67140001,  0.52759999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R203_bz-s7',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 42,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.03874464,  0.05171258,  0.08287273, -0.02347821,  0.90166688,
#          -0.43144685, -0.84550083,  0.21222411,  0.48953027,  0.5334    ,
#           0.37639999,  0.75760001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R205_bz-s8',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 43,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 4.12541255e-02,  1.14840368e-05,  9.36382636e-02, -1.31249577e-02,
#           9.99043703e-01, -3.28355394e-02, -8.65308404e-01,  5.09337848e-03,
#           5.00848889e-01,  5.00599980e-01,  3.50000001e-02,  8.64799976e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R207_bz-s10',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 44,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.04286744, -0.05515818,  0.08126997,  0.00289847,  0.87349087,
#           0.48622116, -0.86417657, -0.24221845,  0.4402943 ,  0.50319999,
#          -0.42160001,  0.75440001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R209_bz-s38',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 45,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.0427002 , -0.0744039 ,  0.06296299,  0.83189827,  0.44851613,
#          -0.32640904, -0.03621958,  0.63101304,  0.77475947,  0.55360001,
#          -0.63279998,  0.54140002]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R210_bz-s66',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 46,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.04294323, -0.08700975,  0.03742657, -0.03798845,  0.25152552,
#           0.96663183, -0.84776455, -0.51952463,  0.10186757,  0.5284    ,
#          -0.81639999,  0.2332    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R211_bz-s34',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 47,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.04387113, -0.08959817, -0.02276572,  0.00110436, -0.00190119,
#           0.9994626 , -0.86417657, -0.50198078,  0.        ,  0.50260001,
#          -0.8646    , -0.0022    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R213_bz-s32',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 48,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.04235097, -0.08695889, -0.08675946,  0.0011056 , -0.00190119,
#           0.99974704, -0.86417657, -0.50254667,  0.        ,  0.50260001,
#          -0.8646    , -0.0022    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R215_bz-s25',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 49,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.0529046 ,  0.08632489,  0.02715006, -0.04412733, -0.48569995,
#           0.87293732,  0.70345217, -0.63554049, -0.31805319,  0.70920002,
#           0.6002    ,  0.3698    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R302_bz-s13',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 50,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.05794381,  0.05202852,  0.06490387, -0.00296129, -0.85096776,
#           0.52471828,  0.71646857, -0.36785513, -0.59252971,  0.69760001,
#           0.37419999,  0.61080003]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R304_bz-s5',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 51,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.06057864,  0.00227985,  0.07993758, -0.01431511, -0.99902785,
#           0.04226384,  0.73853987, -0.03904923, -0.67289191,  0.67379999,
#           0.0216    ,  0.73879999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R306_bz-s69',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 52,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.06155096, -0.0211577 ,  0.07768022, -0.6973629 , -0.18194623,
#           0.69278902, -0.03169213, -0.95812112, -0.2835314 ,  0.71579999,
#          -0.2198    ,  0.66280001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R307_bz-s2',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 53,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.06303836, -0.06489674,  0.04890034, -0.69538993, -0.58877122,
#           0.4116807 , -0.00396152, -0.56989247, -0.82173175,  0.7184    ,
#          -0.57300001,  0.39399999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R309_bz-s27',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 54,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.06148151, -0.0739051 ,  0.01908738, -0.01155054, -0.20043316,
#          -0.97986203,  0.7317487 ,  0.66610074, -0.14487833,  0.6814    ,
#          -0.71880001,  0.139     ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R310_bz-s19',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 55,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.05429425, -0.06560628, -0.05322419, -0.01280905,  0.00886203,
#          -1.00009739,  0.73457837,  0.6785512 , -0.00339559,  0.67839998,
#          -0.73479998, -0.0152    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R312_bz-s33',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 56,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.06429337,  0.07192872, -0.00294196, -0.07626124,  0.28884017,
#          -0.95380998, -0.44934916,  0.84380305,  0.29145443,  0.89020002,
#           0.45100001,  0.0654    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R401_bz-s30',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 57,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.07450945,  0.04648074,  0.03843177, -0.02339219,  0.79582345,
#          -0.60429871, -0.41482738,  0.54216188,  0.73005092,  0.90939999,
#           0.26820001,  0.31799999]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R403_bz-s29',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 58,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 7.79757872e-02, -6.89551161e-05,  5.57021089e-02, -1.97890215e-02,
#           9.99412775e-01,  1.82324853e-02, -4.23316360e-01, -2.49009617e-02,
#           9.05489504e-01,  9.05600011e-01,  1.02000004e-02,  4.23799992e-01]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R405_bz-s40',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 59,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.0800915 , -0.04374276,  0.02579976, -0.13301584,  0.46777895,
#           0.8740204 , -0.40067911, -0.83191848,  0.38426712,  0.9066    ,
#          -0.29899999,  0.29800001]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R407_bz-s26',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 60,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.07595826, -0.04740905, -0.02475704,  0.        ,  0.        ,
#           1.00007796, -0.40294284, -0.91511035,  0.        ,  0.91540003,
#          -0.403     ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R409_bz-s18',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 61,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.08138976,  0.03764319,  0.01337331,  0.26394498, -0.65908694,
#          -0.70414406, -0.12846632,  0.69949067, -0.70288622,  0.95599997,
#           0.27579999,  0.1002    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R503_bz-s17',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 62,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.08471015, -0.01234978,  0.02326602,  0.26268253,  0.6151647 ,
#          -0.74340916, -0.05546124,  0.77872097,  0.62478775,  0.96340001,
#          -0.1228    ,  0.2388    ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R505_bz-s24',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 63,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.08695678, -0.02634335, -0.0295    , -0.1908    , -0.98159999,
#           0.        ,  0.        ,  0.        , -1.        ,  0.98159999,
#          -0.1908    ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R507_bz-s22',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)},
#  {'scanno': 64,
#   'logno': 0,
#   'kind': 1 (FIFFV_MEG_CH),
#   'range': 1.0,
#   'cal': -1.8749804853390945e-15,
#   'coil_type': 8101 (FIFFV_COIL_FIELDLINE_OPM_MAG_GEN1),
#   'loc': array([ 0.08428924,  0.00121799, -0.0574    , -0.017     ,  0.99980003,
#           0.        ,  0.        ,  0.        ,  1.        ,  0.99980003,
#           0.017     ,  0.        ]),
#   'unit': 112 (FIFF_UNIT_T),
#   'unit_mul': 0 (FIFF_UNITM_NONE),
#   'ch_name': 'R606_bz-s14',
#   'coord_frame': 1 (FIFFV_COORD_DEVICE)}]
