# %% [markdown]
# # The Fieldline OPM data set
#
#
# ## Introduction
#
# To demonstrate the functionality of the pipeline, we will be using MEG datasets recorded using SQUID- and OPM-based MEG data employing a spatial attention paradigm. The paradigm is derived from a study involving moving target gratings and the detection of subtle dots (based on [1,2]; see Figure 1). The main advantage of this task is that the allocation of spatial attention produces robust modulations in the 8 – 12 Hz alpha band during the cue-target interval [3]. Furthermore, the moving gratings will induce strong activity in the 60 – 90 Hz gamma band, also modulated by attention.
#
#
# ## The OPM-MEG system
#
# The data were recorded using the OPM-MEG system from Fieldline at CHBH. This system has 76 sensors distributed over the head. Each sensor is uni-axial, meaning that it measures the magnetic field in a single direction. This direction typically corresponds to that of conventional magnetometers, measuring the field component perpendicular to the scalp surface.
#
# The OPM-MEG system is placed in a shielded room (2 layers of mu-metal and 1 layer of aluminium) provided by Cerca.
#
# The peripherals of the OPM-MEG system applied to record the dataset include:
#
# * ProPixx visual projector (1440 Hz refresh rate)
# * Optical button boxes
# * Stimulus delivery computer using PsychoPy.
#
# The trigger were controlled by the stimulus computer communicating with the DataPixx. The DataPixx then sent triggers to the Fieldline controller.
#
# Please see "The Introduction" for where to find the data.
#
#
# ## The paradigm
# Trials started with a fixation dot followed by a cue pointing to the left or right (Figure 1). This indicated to the participants which of the two upcoming stimuli to attend. After a 1 s interval, two inward-moving circular gratings were shown in both hemifields. After a random interval (1 – 2.5 s) a white dot was presented for 50 ms at the centre of the grating in the cued hemifield. Participants were instructed to press a button (right index finger) as soon as they detected the dot. The stimuli presentation were implemented in Python using the PsychoPy and the code can be found on the FLUX website.
#
#
# ![Paradigm](attachment:paradigm.png)
#
# **Figure 1.** *The paradigm used for the OPM-MEG data collection in the FLUX pipeline. A cue directs the participants to attend left or right. This results in strong hemispheric lateralisation of the posterior alpha power (8 – 12 Hz). Then follows the presentation of the moving gratings, which will induce strong gamma power (60 – 90 Hz) in the visual cortex as well as visual evoked fields. Finally, the button response to the dot flash will result in gamma band activity in the motor cortex, followed by suppression in the beta band (15 – 40 Hz). Since the task produces robust and well-documented modulations in the alpha, beta and gamma band as well as event-related fields, it is well suited for the FLUX pipeline with a focus on the characterisation of oscillatory brain activity in the visual and motor regions as well as source modelling.*
#
#
# **Question 1:** How might the alpha band and gamma band activity specifically be modulated with respect to left versus right directed attention?
#
# **Question 2:** In which brain regions might the strongest modulation of alpha and gamma activity be expected?
#
# **Question 3:** Provide examples of event-related fields generated and evoked by the various task components.
#
#
# ## Preregistration and publication
#
#
# Publication example. Describe the relevant parameters of the tasks:
#
# "Each trial started with a fixation dot followed by a cue pointing to the left or right (Figure 1). This indicated to the participants which of the two upcoming stimuli to attend to. After a 1 s interval, two inward-moving circular gratings were shown in both hemifields. The cue was randomly to the left or the right. After a random interval (1 – 2.5 s), a white dot was presented for 50 ms at the centre of the grating in the cued hemifield. The gratings always remained on for 3.0 s. Participants were instructed to press a button (right index finger) as soon as they detected the dot. The moving gratings were centred at +/- 4 degrees. They were each 2 degrees wide. In total 100 trials were presented to each participant. The stimulus presentation was implemented in PsychoPy.  "
#
#
# ## References
#
#
# [1] Grent-’t-Jong, T., Rivolta, D., Gross, J., Gajwani, R., Lawrie, S.M., Schwannauer, M., Heidegger, T., Wibral, M., Singer, W., Sauer, A., Scheller, B., Uhlhaas, P.J., 2018. Acute ketamine dysregulates task-related gamma-band oscillations in thalamo-cortical circuits in schizophrenia. Brain 141, 2511–2526.
#
# [2] Hoogenboom, N., Schoffelen, J.-M., Oostenveld, R., Parkes, L.M., Fries, P., 2006. Localizing human visual gamma-band activity in frequency, time and space. Neuroimage 29, 764–773.
#
# [3] Jensen, O., and Hanslmayr, S., 2020. The Role of Alpha Oscillations for Attention and Working Memory. In. Poeppel, D., Mangun, G.R., and Gazzaniga, M.S. (eds) The cognitive neurosciences, 6th MIT Press.
